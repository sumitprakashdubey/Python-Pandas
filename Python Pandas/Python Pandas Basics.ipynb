# %% [markdown]
# https://www.youtube.com/watch?v=RtM2mx5qq0k&t=2956s&ab_channel=SumeetAnalytics

# %%
import pandas as pd

# %%
df=pd.read_csv('HDFC.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2     HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3     HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4     HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   HDFC     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   HDFC     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   HDFC     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   HDFC     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   HDFC     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df.tail()
# Out:
#     Symbol Series      Date  Prev Close  Open Price  High Price  Low Price  \
# 576   HDFC     W3  3-Dec-20      549.00      559.00       559.0      539.0
# 577   HDFC     EQ  4-Dec-20     2253.95     2253.95      2284.9     2231.6
# 578   HDFC     W3  4-Dec-20      542.70      550.00       560.0      540.0
# 579   HDFC     EQ  7-Dec-20     2245.90     2240.00      2309.7     2221.2
# 580   HDFC     W3  7-Dec-20      545.35      550.00       577.9      550.0
#
#      Last Price  Close Price  Average Price
# 576      542.55       542.70         542.00
# 577     2247.20      2245.90        2253.16
# 578      543.00       545.35         548.29
# 579     2303.00      2303.80        2281.80
# 580      575.00       571.80         567.63

# %%
df.head(10)
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
# 5   HDFC    NaN  17-Dec-18     1904.10     1915.00     1963.40    1913.70
# 6   HDFC    NaN  18-Dec-18     1960.35     1955.00     1957.90    1932.50
# 7   HDFC     EQ  19-Dec-18     1952.00     1954.00     1985.50    1948.55
# 8   HDFC     EQ  20-Dec-18     1981.70     1970.00     1982.00    1943.05
# 9   HDFC     EQ  21-Dec-18     1974.70     1974.80     1979.60    1930.00
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# ...

# %%
df.tail(9)
# Out:
#     Symbol Series      Date  Prev Close  Open Price  High Price  Low Price  \
# 572   HDFC     W3  1-Dec-20      542.10      550.00      578.00     541.05
# 573   HDFC     EQ  2-Dec-20     2306.95     2300.00     2304.00    2252.50
# 574   HDFC     W3  2-Dec-20      575.30      571.00      571.00     549.00
# 575   HDFC     EQ  3-Dec-20     2276.35     2287.00     2289.45    2235.00
# 576   HDFC     W3  3-Dec-20      549.00      559.00      559.00     539.00
# 577   HDFC     EQ  4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   HDFC     W3  4-Dec-20      542.70      550.00      560.00     540.00
# 579   HDFC     EQ  7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   HDFC     W3  7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# 572      572.00       575.30         565.82
# 573     2274.00      2276.35        2276.62
# 574      549.00       549.00         552.14
# ...

# %%
df.columns
# Out:
# Index(['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price',
#        'Low Price', 'Last Price', 'Close Price', 'Average Price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=581, step=1)

# %%
df.size
# Out:
# 5810

# %%
df.shape
# Out:
# (581, 10)

# %%
df.dtypes
# Out:
# Symbol            object
# Series            object
# Date              object
# Prev Close       float64
# Open Price       float64
# High Price       float64
# Low Price        float64
# Last Price       float64
# Close Price      float64
# Average Price    float64
# dtype: object

# %%
df.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count   581.000000   581.000000   581.000000   581.000000   581.000000
# mean   1790.647590  1794.082014  1817.678744  1769.438296  1793.409983
# std     609.184039   608.099690   612.293946   602.063847   607.473777
# min     180.000000   295.000000   299.950000   295.000000   298.200000
# 25%    1760.750000  1766.000000  1793.250000  1740.000000  1764.000000
# 50%    1961.250000  1964.000000  1985.000000  1941.600000  1964.000000
# 75%    2172.800000  2174.000000  2193.000000  2140.000000  2171.000000
# max    2492.300000  2486.000000  2499.900000  2471.800000  2491.700000
#
#        Close Price  Average Price
# count   574.000000     581.000000
# mean   1791.418467    1793.486627
# std     611.088312     607.057205
# min     298.200000     298.770000
# 25%    1759.250000    1768.630000
# 50%    1965.300000    1961.650000
# 75%    2174.975000    2168.720000
# max    2492.300000    2483.170000

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df.at[4,'Prev Close']
# Out:
# 1942.05

# %%
df.iat[4,3]
# Out:
# 1942.05

# %%
df.loc[4]
# Out:
# Symbol                HDFC
# Series                 NaN
# Date             14-Dec-18
# Prev Close         1942.05
# Open Price            1945
# High Price            1955
# Low Price          1898.05
# Last Price          1909.6
# Close Price            NaN
# Average Price      1913.13
# Name: 4, dtype: object

# %%
df.iloc[4]
# Out:
# Symbol                HDFC
# Series                 NaN
# Date             14-Dec-18
# Prev Close         1942.05
# Open Price            1945
# High Price            1955
# Low Price          1898.05
# Last Price          1909.6
# Close Price            NaN
# Average Price      1913.13
# Name: 4, dtype: object

# %%
df.loc[10:20]
# Out:
#    Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 10   HDFC     EQ  24-Dec-18     1948.60     1955.00     1955.00    1898.00
# 11   HDFC     EQ  26-Dec-18     1902.15     1896.00     1944.70    1883.20
# 12   HDFC     EQ  27-Dec-18     1933.35     1948.45     1955.00    1930.00
# 13   HDFC     EQ  28-Dec-18     1948.85     1959.00     1990.00    1952.00
# 14   HDFC     EQ  31-Dec-18     1979.95     1988.00     1989.75    1961.55
# 15   HDFC     EQ   1-Jan-19     1968.35     1968.00     2014.70    1954.50
# 16   HDFC     EQ   2-Jan-19     2009.00     2004.70     2009.00    1961.00
# 17   HDFC     EQ   3-Jan-19     1980.65     1984.05     1987.10    1931.85
# 18   HDFC     EQ   4-Jan-19     1936.85     1948.00     1976.00    1942.00
# 19   HDFC     EQ   7-Jan-19     1972.60     1976.95     1987.50    1963.95
# 20   HDFC     EQ   8-Jan-19     1972.90     1983.00     1983.00    1948.00
#
#     Last Price  Close Price  Average Price
# ...

# %%
df.iloc[10:20]
# Out:
#    Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 10   HDFC     EQ  24-Dec-18     1948.60     1955.00     1955.00    1898.00
# 11   HDFC     EQ  26-Dec-18     1902.15     1896.00     1944.70    1883.20
# 12   HDFC     EQ  27-Dec-18     1933.35     1948.45     1955.00    1930.00
# 13   HDFC     EQ  28-Dec-18     1948.85     1959.00     1990.00    1952.00
# 14   HDFC     EQ  31-Dec-18     1979.95     1988.00     1989.75    1961.55
# 15   HDFC     EQ   1-Jan-19     1968.35     1968.00     2014.70    1954.50
# 16   HDFC     EQ   2-Jan-19     2009.00     2004.70     2009.00    1961.00
# 17   HDFC     EQ   3-Jan-19     1980.65     1984.05     1987.10    1931.85
# 18   HDFC     EQ   4-Jan-19     1936.85     1948.00     1976.00    1942.00
# 19   HDFC     EQ   7-Jan-19     1972.60     1976.95     1987.50    1963.95
#
#     Last Price  Close Price  Average Price
# 10     1906.75          NaN        1925.72
# 11     1938.00      1933.35        1910.40
# ...

# %%
df.loc[[45,60,70,120]]
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 45    HDFC     EQ  11-Feb-19     1944.65      1943.9     1959.00     1935.6
# 60    HDFC     EQ  28-Feb-19     1841.00      1849.0     1853.65     1834.6
# 70    HDFC     EQ  15-Mar-19     1956.95      1960.0     1991.70     1955.9
# 120   HDFC     EQ  30-May-19     2147.45      2141.4     2189.45     2130.0
#
#      Last Price  Close Price  Average Price
# 45      1951.25      1948.20        1947.12
# 60      1841.80      1841.20        1841.82
# 70      1976.80      1974.65        1972.90
# 120     2179.10      2184.40        2169.63

# %%
df.iloc[-12:-10]
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 569   HDFC     EQ  27-Nov-20      2238.4      2240.0     2272.45     2202.2
# 570   HDFC     W3  27-Nov-20       525.0       525.0      545.00      521.0
#
#      Last Price  Close Price  Average Price
# 569      2238.0      2256.25        2239.94
# 570       535.0       542.10         528.67

# %%
df.iloc[-10:]
# Out:
#     Symbol Series      Date  Prev Close  Open Price  High Price  Low Price  \
# 571   HDFC     EQ  1-Dec-20     2256.25     2237.00     2324.00    2217.65
# 572   HDFC     W3  1-Dec-20      542.10      550.00      578.00     541.05
# 573   HDFC     EQ  2-Dec-20     2306.95     2300.00     2304.00    2252.50
# 574   HDFC     W3  2-Dec-20      575.30      571.00      571.00     549.00
# 575   HDFC     EQ  3-Dec-20     2276.35     2287.00     2289.45    2235.00
# 576   HDFC     W3  3-Dec-20      549.00      559.00      559.00     539.00
# 577   HDFC     EQ  4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   HDFC     W3  4-Dec-20      542.70      550.00      560.00     540.00
# 579   HDFC     EQ  7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   HDFC     W3  7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# 571     2296.20      2306.95        2283.03
# 572      572.00       575.30         565.82
# ...

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df.T
# Out:
#                      0          1          2          3          4    \
# Symbol              HDFC       HDFC       HDFC       HDFC       HDFC
# Series                EQ         EQ        NaN        NaN        NaN
# Date           10-Dec-18  11-Dec-18  12-Dec-18  13-Dec-18  14-Dec-18
# Prev Close       1951.35     1906.5    1905.25     1940.2    1942.05
# Open Price       1924.35       1878       1912       1945       1945
# High Price        1939.9    1912.65     1946.8     1961.9       1955
# Low Price        1901.25    1855.25    1904.25     1927.9    1898.05
# Last Price          1905       1904       1937    1941.45     1909.6
# Close Price       1906.5    1905.25     1940.2    1942.05        NaN
# Average Price    1917.18    1885.14    1923.88    1943.93    1913.13
#
#                      5          6          7          8          9    ...  \
# Symbol              HDFC       HDFC       HDFC       HDFC       HDFC  ...
# ...

# %%
np=df.values

# %%
type(np)
# Out:
# numpy.ndarray

# %%
np
# Out:
# array([['HDFC', 'EQ', '10-Dec-18', ..., 1905.0, 1906.5, 1917.18],
#        ['HDFC', 'EQ', '11-Dec-18', ..., 1904.0, 1905.25, 1885.14],
#        ['HDFC', nan, '12-Dec-18', ..., 1937.0, 1940.2, 1923.88],
#        ...,
#        ['HDFC', 'W3', '4-Dec-20', ..., 543.0, 545.35, 548.29],
#        ['HDFC', 'EQ', '7-Dec-20', ..., 2303.0, 2303.8, 2281.8],
#        ['HDFC', 'W3', '7-Dec-20', ..., 575.0, 571.8, 567.63]],
#       dtype=object)

# %%
df.head(100).tail(2)
# Out:
#    Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 98   HDFC     EQ  26-Apr-19     1955.15      1959.3     1982.15     1941.6
# 99   HDFC     EQ  30-Apr-19     1977.40      1977.4     1999.85     1954.2
#
#     Last Price  Close Price  Average Price
# 98     1976.95      1977.40        1963.96
# 99     1995.55      1995.05        1976.43

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df.isna()
# Out:
#      Symbol  Series   Date  Prev Close  Open Price  High Price  Low Price  \
# 0     False   False  False       False       False       False      False
# 1     False   False  False       False       False       False      False
# 2     False    True  False       False       False       False      False
# 3     False    True  False       False       False       False      False
# 4     False    True  False       False       False       False      False
# ..      ...     ...    ...         ...         ...         ...        ...
# 576   False   False  False       False       False       False      False
# 577   False   False  False       False       False       False      False
# 578   False   False  False       False       False       False      False
# 579   False   False  False       False       False       False      False
# 580   False   False  False       False       False       False      False
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.fillna(0)
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2     HDFC      0  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3     HDFC      0  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4     HDFC      0  14-Dec-18     1942.05     1945.00     1955.00    1898.05
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   HDFC     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   HDFC     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   HDFC     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   HDFC     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   HDFC     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df['Close Price'].fillna(0)
# Out:
# 0      1906.50
# 1      1905.25
# 2      1940.20
# 3      1942.05
# 4         0.00
#         ...
# 576     542.70
# 577    2245.90
# 578     545.35
# 579    2303.80
# 580     571.80
# Name: Close Price, Length: 581, dtype: float64

# %%
df['Close Price']
# Out:
# 0      1906.50
# 1      1905.25
# 2      1940.20
# 3      1942.05
# 4          NaN
#         ...
# 576     542.70
# 577    2245.90
# 578     545.35
# 579    2303.80
# 580     571.80
# Name: Close Price, Length: 581, dtype: float64

# %%
df.dropna()
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 11    HDFC     EQ  26-Dec-18     1902.15     1896.00     1944.70    1883.20
# 12    HDFC     EQ  27-Dec-18     1933.35     1948.45     1955.00    1930.00
# 13    HDFC     EQ  28-Dec-18     1948.85     1959.00     1990.00    1952.00
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   HDFC     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   HDFC     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   HDFC     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   HDFC     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   HDFC     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.dropna(subset=['Close Price'])
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2     HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3     HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 11    HDFC     EQ  26-Dec-18     1902.15     1896.00     1944.70    1883.20
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   HDFC     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   HDFC     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   HDFC     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   HDFC     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   HDFC     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.dropna(subset=['Close Price','Series'])
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 11    HDFC     EQ  26-Dec-18     1902.15     1896.00     1944.70    1883.20
# 12    HDFC     EQ  27-Dec-18     1933.35     1948.45     1955.00    1930.00
# 13    HDFC     EQ  28-Dec-18     1948.85     1959.00     1990.00    1952.00
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   HDFC     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   HDFC     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   HDFC     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   HDFC     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   HDFC     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.dropna(subset=['Close Price','Series'],how='all',inplace=True)
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2     HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3     HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 7     HDFC     EQ  19-Dec-18     1952.00     1954.00     1985.50    1948.55
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   HDFC     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   HDFC     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   HDFC     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   HDFC     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   HDFC     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2     HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3     HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4     HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   HDFC     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   HDFC     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   HDFC     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   HDFC     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   HDFC     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.max()
# Out:
# Symbol               HDFC
# Date             9-Sep-20
# Prev Close         2492.3
# Open Price           2486
# High Price         2499.9
# Low Price          2471.8
# Last Price         2491.7
# Close Price        2492.3
# Average Price     2483.17
# dtype: object

# %%
df.min()
# Out:
# Symbol               HDFC
# Date             1-Apr-19
# Prev Close            180
# Open Price            295
# High Price         299.95
# Low Price             295
# Last Price          298.2
# Close Price         298.2
# Average Price      298.77
# dtype: object

# %%
df.mean()
# Out:
# Prev Close       1790.647590
# Open Price       1794.082014
# High Price       1817.678744
# Low Price        1769.438296
# Last Price       1793.409983
# Close Price      1791.418467
# Average Price    1793.486627
# dtype: float64

# %%
df.sum()
# Out:
# Symbol           HDFCHDFCHDFCHDFCHDFCHDFCHDFCHDFCHDFCHDFCHDFCHD...
# Date             10-Dec-1811-Dec-1812-Dec-1813-Dec-1814-Dec-181...
# Prev Close                                             1.04037e+06
# Open Price                                             1.04236e+06
# High Price                                             1.05607e+06
# Low Price                                              1.02804e+06
# Last Price                                             1.04197e+06
# Close Price                                            1.02827e+06
# Average Price                                          1.04202e+06
# dtype: object

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df.replace('HDFC','Hdfc')
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     Hdfc     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     Hdfc     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2     Hdfc    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3     Hdfc    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4     Hdfc    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   Hdfc     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   Hdfc     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   Hdfc     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   Hdfc     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   Hdfc     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df['Series'].unique()
# Out:
# array(['EQ', nan, 'BL', 'W3'], dtype=object)

# %%
df['Series'].nunique()
# Out:
# 3

# %%
df['Series'].value_counts()
# Out:
# EQ    490
# W3     81
# BL      5
# Name: Series, dtype: int64

# %%
grp_df=df.groupby(by=['Series'])

# %%
type(grp_df)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grp_df.mean()
# Out:
#          Prev Close   Open Price   High Price    Low Price   Last Price  \
# Series
# BL      1790.440000  1947.900000  1947.900000  1947.900000  1947.900000
# EQ      2022.532551  2024.483265  2050.806122  1996.429082  2023.330918
# W3       379.273457   382.140123   390.763580   376.265432   383.943827
#
#         Close Price  Average Price
# Series
# BL      1947.900000    1947.900000
# EQ      2023.743827    2023.530918
# W3       384.110494     383.682963

# %%
grp_df.count()
# Out:
#         Symbol  Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# BL           5     5           5           5           5          5
# EQ         490   490         490         490         490        490
# W3          81    81          81          81          81         81
#
#         Last Price  Close Price  Average Price
# Series
# BL               5            5              5
# EQ             490          486            490
# W3              81           81             81

# %%
grp_df.max()
# Out:
#        Symbol       Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# BL       HDFC  25-Feb-19     1987.55      2045.0      2045.0     2045.0
# EQ       HDFC   9-Sep-20     2492.30      2486.0      2499.9     2471.8
# W3       HDFC   9-Sep-20      575.30       571.0       578.0      550.0
#
#         Last Price  Close Price  Average Price
# Series
# BL          2045.0       2045.0        2045.00
# EQ          2491.7       2492.3        2483.17
# W3           575.0        575.3         567.63

# %%
grp_df.min()
# Out:
#        Symbol       Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# BL       HDFC  11-Feb-19     1257.70      1874.9     1874.90    1874.90
# EQ       HDFC   1-Apr-19     1499.55      1476.0     1568.15    1473.45
# W3       HDFC   1-Dec-20      180.00       295.0      299.95     295.00
#
#         Last Price  Close Price  Average Price
# Series
# BL         1874.90      1874.90        1874.90
# EQ         1499.75      1499.55        1512.61
# W3          298.20       298.20         298.77

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df[df['Date']=='14-Dec-18']
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 4   HDFC    NaN  14-Dec-18     1942.05      1945.0      1955.0    1898.05
#
#    Last Price  Close Price  Average Price
# 4      1909.6          NaN        1913.13

# %%
df[(df['Date']=='14-Dec-18') & (df['High Price']>100)]
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 4   HDFC    NaN  14-Dec-18     1942.05      1945.0      1955.0    1898.05
#
#    Last Price  Close Price  Average Price
# 4      1909.6          NaN        1913.13

# %%
df[df['Series'].isin(['BL','EQ'])]
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 7     HDFC     EQ  19-Dec-18     1952.00     1954.00     1985.50    1948.55
# 8     HDFC     EQ  20-Dec-18     1981.70     1970.00     1982.00    1943.05
# 9     HDFC     EQ  21-Dec-18     1974.70     1974.80     1979.60    1930.00
# ..     ...    ...        ...         ...         ...         ...        ...
# 571   HDFC     EQ   1-Dec-20     2256.25     2237.00     2324.00    2217.65
# 573   HDFC     EQ   2-Dec-20     2306.95     2300.00     2304.00    2252.50
# 575   HDFC     EQ   3-Dec-20     2276.35     2287.00     2289.45    2235.00
# 577   HDFC     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 579   HDFC     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
#
#      Last Price  Close Price  Average Price
# ...

# %%
df[df['Prev Close'].between(100,500)]
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 420   HDFC     W3  13-Aug-20      180.00      310.20      339.00     299.00
# 422   HDFC     W3  14-Aug-20      299.95      300.00      320.00     300.00
# 424   HDFC     W3  17-Aug-20      309.00      315.00      319.50     312.00
# 426   HDFC     W3  18-Aug-20      315.40      319.90      325.00     319.90
# 428   HDFC     W3  19-Aug-20      322.25      325.00      329.00     323.00
# ..     ...    ...        ...         ...         ...         ...        ...
# 536   HDFC     W3   4-Nov-20      415.15      415.00      450.00     412.55
# 538   HDFC     W3   5-Nov-20      442.60      440.00      452.90     434.05
# 540   HDFC     W3   6-Nov-20      435.00      446.90      458.00     445.15
# 542   HDFC     W3   9-Nov-20      445.15      459.95      489.65     459.90
# 544   HDFC     W3  10-Nov-20      479.00      509.70      526.90     506.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   HDFC     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   HDFC     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   HDFC    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   HDFC    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   HDFC    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df['Symbol']='hdfc'

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   hdfc     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   hdfc     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   hdfc    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   hdfc    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   hdfc    NaN  14-Dec-18     1942.05     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df.at[4,'Prev Close']=2000

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   hdfc     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   hdfc     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   hdfc    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   hdfc    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4   hdfc    NaN  14-Dec-18     2000.00     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df.loc[3,'Prev Close']=2000

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   hdfc     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1   hdfc     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2   hdfc    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3   hdfc    NaN  13-Dec-18     2000.00     1945.00     1961.90    1927.90
# 4   hdfc    NaN  14-Dec-18     2000.00     1945.00     1955.00    1898.05
#
#    Last Price  Close Price  Average Price
# 0     1905.00      1906.50        1917.18
# 1     1904.00      1905.25        1885.14
# 2     1937.00      1940.20        1923.88
# 3     1941.45      1942.05        1943.93
# 4     1909.60          NaN        1913.13

# %%
df.sort_index()
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     hdfc     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     hdfc     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2     hdfc    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3     hdfc    NaN  13-Dec-18     2000.00     1945.00     1961.90    1927.90
# 4     hdfc    NaN  14-Dec-18     2000.00     1945.00     1955.00    1898.05
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   hdfc     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   hdfc     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   hdfc     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   hdfc     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   hdfc     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.sort_values(by=['Average Price'])
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 488   hdfc     W3  30-Sep-20      299.00      295.00      299.95     295.00
# 480   hdfc     W3  24-Sep-20      298.20      299.95      300.00     295.70
# 482   hdfc     W3  25-Sep-20      300.00      299.95      300.00     296.15
# 478   hdfc     W3  23-Sep-20      300.00      298.00      301.00     297.00
# 484   hdfc     W3  28-Sep-20      300.00      300.00      300.00     298.00
# ..     ...    ...        ...         ...         ...         ...        ...
# 279   hdfc     EQ  21-Jan-20     2454.35     2443.00     2485.90    2432.00
# 277   hdfc     EQ  17-Jan-20     2482.10     2467.75     2479.00    2448.25
# 274   hdfc     EQ  14-Jan-20     2462.55     2463.65     2499.90    2446.60
# 275   hdfc     EQ  15-Jan-20     2492.30     2483.95     2495.00    2453.55
# 276   hdfc     EQ  16-Jan-20     2488.60     2486.00     2495.75    2471.80
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.sort_values(by=['Average Price'],ascending=False,inplace=True)

# %%
df.sort_values(by=['Average Price','Close Price'],ascending=False,inplace=True)

# %%
df
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 276   hdfc     EQ  16-Jan-20     2488.60     2486.00     2495.75    2471.80
# 275   hdfc     EQ  15-Jan-20     2492.30     2483.95     2495.00    2453.55
# 274   hdfc     EQ  14-Jan-20     2462.55     2463.65     2499.90    2446.60
# 277   hdfc     EQ  17-Jan-20     2482.10     2467.75     2479.00    2448.25
# 279   hdfc     EQ  21-Jan-20     2454.35     2443.00     2485.90    2432.00
# ..     ...    ...        ...         ...         ...         ...        ...
# 484   hdfc     W3  28-Sep-20      300.00      300.00      300.00     298.00
# 478   hdfc     W3  23-Sep-20      300.00      298.00      301.00     297.00
# 482   hdfc     W3  25-Sep-20      300.00      299.95      300.00     296.15
# 480   hdfc     W3  24-Sep-20      298.20      299.95      300.00     295.70
# 488   hdfc     W3  30-Sep-20      299.00      295.00      299.95     295.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.sort_index()
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     hdfc     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     hdfc     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2     hdfc    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3     hdfc    NaN  13-Dec-18     1940.20     1945.00     1961.90    1927.90
# 4     hdfc    NaN  14-Dec-18     2000.00     1945.00     1955.00    1898.05
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   hdfc     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   hdfc     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   hdfc     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   hdfc     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   hdfc     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     hdfc     EQ  10-Dec-18     1951.35     1924.35     1939.90    1901.25
# 1     hdfc     EQ  11-Dec-18     1906.50     1878.00     1912.65    1855.25
# 2     hdfc    NaN  12-Dec-18     1905.25     1912.00     1946.80    1904.25
# 3     hdfc    NaN  13-Dec-18     2000.00     1945.00     1961.90    1927.90
# 4     hdfc    NaN  14-Dec-18     2000.00     1945.00     1955.00    1898.05
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   hdfc     W3   3-Dec-20      549.00      559.00      559.00     539.00
# 577   hdfc     EQ   4-Dec-20     2253.95     2253.95     2284.90    2231.60
# 578   hdfc     W3   4-Dec-20      542.70      550.00      560.00     540.00
# 579   hdfc     EQ   7-Dec-20     2245.90     2240.00     2309.70    2221.20
# 580   hdfc     W3   7-Dec-20      545.35      550.00      577.90     550.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df.reset_index(drop=True)
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     hdfc     EQ  16-Jan-20     2488.60     2486.00     2495.75    2471.80
# 1     hdfc     EQ  15-Jan-20     2492.30     2483.95     2495.00    2453.55
# 2     hdfc     EQ  14-Jan-20     2462.55     2463.65     2499.90    2446.60
# 3     hdfc     EQ  17-Jan-20     2482.10     2467.75     2479.00    2448.25
# 4     hdfc     EQ  21-Jan-20     2454.35     2443.00     2485.90    2432.00
# ..     ...    ...        ...         ...         ...         ...        ...
# 576   hdfc     W3  28-Sep-20      300.00      300.00      300.00     298.00
# 577   hdfc     W3  23-Sep-20      300.00      298.00      301.00     297.00
# 578   hdfc     W3  25-Sep-20      300.00      299.95      300.00     296.15
# 579   hdfc     W3  24-Sep-20      298.20      299.95      300.00     295.70
# 580   hdfc     W3  30-Sep-20      299.00      295.00      299.95     295.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df
# Out:
#      index Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0      276   hdfc     EQ  16-Jan-20     2488.60     2486.00     2495.75
# 1      275   hdfc     EQ  15-Jan-20     2492.30     2483.95     2495.00
# 2      274   hdfc     EQ  14-Jan-20     2462.55     2463.65     2499.90
# 3      277   hdfc     EQ  17-Jan-20     2482.10     2467.75     2479.00
# 4      279   hdfc     EQ  21-Jan-20     2454.35     2443.00     2485.90
# ..     ...    ...    ...        ...         ...         ...         ...
# 576    484   hdfc     W3  28-Sep-20      300.00      300.00      300.00
# 577    478   hdfc     W3  23-Sep-20      300.00      298.00      301.00
# 578    482   hdfc     W3  25-Sep-20      300.00      299.95      300.00
# 579    480   hdfc     W3  24-Sep-20      298.20      299.95      300.00
# 580    488   hdfc     W3  30-Sep-20      299.00      295.00      299.95
#
#      Low Price  Last Price  Close Price  Average Price
# ...

# %%
df[df['Date'].duplicated()]
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 197   hdfc     BL  23-Sep-19     1987.55     2045.00     2045.00    2045.00
# 74    hdfc     BL  22-Mar-19     1887.40     1987.55     1987.55    1987.55
# 44    hdfc     BL  11-Feb-19     1257.70     1944.65     1944.65    1944.65
# 57    hdfc     EQ  25-Feb-19     1887.40     1897.90     1897.90    1871.50
# 51    hdfc     EQ  18-Feb-19     1874.90     1877.30     1893.00    1864.05
# ..     ...    ...        ...         ...         ...         ...        ...
# 484   hdfc     W3  28-Sep-20      300.00      300.00      300.00     298.00
# 478   hdfc     W3  23-Sep-20      300.00      298.00      301.00     297.00
# 482   hdfc     W3  25-Sep-20      300.00      299.95      300.00     296.15
# 480   hdfc     W3  24-Sep-20      298.20      299.95      300.00     295.70
# 488   hdfc     W3  30-Sep-20      299.00      295.00      299.95     295.00
#
#      Last Price  Close Price  Average Price
# ...

# %%
df[df.duplicated(subset=['Series','Date'])]
# Out:
# Empty DataFrame
# Columns: [Symbol, Series, Date, Prev Close, Open Price, High Price, Low Price, Last Price, Close Price, Average Price]
# Index: []

# %%
df.drop_duplicates(subset=['Date'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-3b4e01961e9b> in <module>
# ----> 1 df[df['Date'].drop_duplicates(keep='first')]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
len(df)
# Out:
# 581

# %%
len(df.drop_duplicates(subset=['Date']))
# Out:
# 495

# %%
plt_df=df.head(20)

# %%
plt_df.plot()
# Out:
# <AxesSubplot:>

# %%
plt_df.plot(x='Date',y='Prev Close')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt_df.plot(x='Date',y='Prev Close',kind='pie')
# Out:
# <AxesSubplot:ylabel='Prev Close'>

# %%
plt_df.plot(x='Date',y='Prev Close',kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt_df.plot(x='Date',y='Prev Close',kind='barh')
# Out:
# <AxesSubplot:ylabel='Date'>

# %%
plt_df.plot(y='Prev Close',kind='box')
# Out:
# <AxesSubplot:>

# %%
plt_df.plot(x='Open Price',y='Prev Close',kind='scatter')
# Out:
# <AxesSubplot:xlabel='Open Price', ylabel='Prev Close'>
